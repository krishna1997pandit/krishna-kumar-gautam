# %% [markdown]
# <a href="https://colab.research.google.com/github/krishna1997pandit/krishna-kumar-gautam/blob/main/jar%20app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #import library and module in python

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #read this excel file

# %%
data = pd.read_excel("Walmart Sales.xlsx")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      A  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      B     Yangon        Member    Male
# 4    373-73-7910      C     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      A  Naypyitaw        Normal    Male
# 996  303-96-2227      A   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      B     Yangon        Normal    Male
# 999  849-09-3807      C     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date      Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08:00
# 1    Electronic accessories       15.28         5   3/8/2019  10:29:00
# ...

# %% [markdown]
# #investigation of data

# %%
data.describe()
# Out:
#         Unit price     Quantity      Rating
# count  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000     6.97270
# std      26.494628     2.923431     1.71858
# min      10.080000     1.000000     4.00000
# 25%      32.875000     3.000000     5.50000
# 50%      55.230000     5.000000     7.00000
# 75%      77.935000     8.000000     8.50000
# max      99.960000    10.000000    10.00000

# %% [markdown]
# #check null value

# %%
data.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Date             0
# Time             0
# Payment          0
# Rating           0
# dtype: int64

# %% [markdown]
# A. Analyze the performance of sales and revenue at the city and branch level.

# %%
data["sales"]=data["Unit price"]*data["Quantity"]
data["sales"]
# Out:
# 0      522.83
# 1       76.40
# 2      324.31
# 3      465.76
# 4      604.17
#         ...
# 995     40.35
# 996    973.80
# 997     31.84
# 998     65.82
# 999    618.38
# Name: sales, Length: 1000, dtype: float64

# %%
data.groupby(["City","Branch"])["sales"].sum()
# Out:
# City       Branch
# Mandalay   A         34130.09
#            B         37215.93
#            C         29794.62
# Naypyitaw  A         35985.64
#            B         35157.75
#            C         34160.14
# Yangon     A         33647.27
#            B         35193.51
#            C         32302.43
# Name: sales, dtype: float64

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date      Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08:00
# 1  Electronic accessories       15.28         5   3/8/2019  10:29:00
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23:00
# 3       Health and beauty       58.22         8  1/27/2019  20:33:00
# 4       Sports and travel       86.31         7   2/8/2019  10:37:00
#
#        Payment  Rating   sales
# 0      Ewallet     9.1  522.83
# 1         Cash     9.6   76.40
# 2  Credit card     7.4  324.31
# 3      Ewallet     8.4  465.76
# 4      Ewallet     5.3  604.17

# %% [markdown]
# average price of an sold item at each branch of the city

# %%
data.groupby(["City","Branch"])["sales"].mean()
# Out:
# City       Branch
# Mandalay   A         286.807479
#            B         315.389237
#            C         313.627579
# Naypyitaw  A         327.142182
#            B         322.548165
#            C         313.395780
# Yangon     A         295.151491
#            B         311.446991
#            C         285.862212
# Name: sales, dtype: float64

# %%
C. analyze performance

# %%
grouped_data = data.groupby(["Product line", "Gender", "Payment"])

# %%
monthly_sales = grouped_data["sales"].sum().unstack(level=0)
monthly_sales
# Out:
# Product line        Electronic accessories  Fashion accessories  \
# Gender Payment
# Female Cash                       10680.68              8885.41
#        Credit card                 8640.40              9157.17
#        Ewallet                     6490.37             10945.42
# Male   Cash                        9062.16              7889.63
#        Credit card                 6052.95              7352.42
#        Ewallet                    10823.47              7489.85
#
# Product line        Food and beverages  Health and beauty  Home and lifestyle  \
# Gender Payment
# Female Cash                   12215.36            6652.14             8791.49
#        Credit card            10485.47            5333.94             9057.82
#        Ewallet                 8890.52            5691.05            10757.24
# Male   Cash                    6080.71            9718.44             8912.32
#        Credit card             8786.14            9875.08             4259.39
# ...

# %% [markdown]
# # 2. App Exploration

# %% [markdown]
# #Features of the Jar app:
# * **Budgeting and expanense tracking :** user can create budgets ,track their expense and set financial goals.
#
# * **Bill management :** user can pay their bills track their docuument.
#
# * **financial advice**
# * **Credit monitring**
#
# # User experince of the jar app:
# * **easy to use**
# * **Personalized**
# * **The app has a clean and modern designing.**

# %% [markdown]
# #additional suggestion
# * Improve the search functionality: Make it easier for users to find the information they need by improving the search functionality.
#
# * Provide more personalized recommendations: Use data collected during the onboarding process and user interactions to provide more personalized recommendations for products and services.

# %% [markdown]
# 3.
